# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np
from sklearn.base import BaseEstimator,TransformerMixin, ClassifierMixin
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.linear_model import ElasticNetCV, LassoLarsCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import make_pipeline, make_union
from sklearn.utils import check_array
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection
from sklearn.decomposition import PCA, FastICA
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold, cross_val_score


class StackingEstimator(BaseEstimator, TransformerMixin):
    
    def __init__(self, estimator):
        self.estimator = estimator

    def fit(self, X, y=None, **fit_params):
        self.estimator.fit(X, y, **fit_params)
        return self
    def transform(self, X):
        X = check_array(X)
        X_transformed = np.copy(X)
        # add class probabilities as a synthetic feature
        if issubclass(self.estimator.__class__, ClassifierMixin) and hasattr(self.estimator, 'predict_proba'):
            X_transformed = np.hstack((self.estimator.predict_proba(X), X))

        # add class prodiction as a synthetic feature
        X_transformed = np.hstack((np.reshape(self.estimator.predict(X), (-1, 1)), X_transformed))

        return X_transformed


train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')

for c in train.columns:
    if train[c].dtype == 'object':
        lbl = LabelEncoder()
        lbl.fit(list(train[c].values) + list(test[c].values))
        train[c] = lbl.transform(list(train[c].values))
        test[c] = lbl.transform(list(test[c].values))

# %%
train.shape, test.shape
# Out:
# ((4209, 378), (4209, 377))

# %%
train.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>y</th>
#       <th>X0</th>
#       <th>X1</th>
#       <th>X2</th>
#       <th>X3</th>
#       <th>X4</th>
#       <th>X5</th>
#       <th>X6</th>
#       <th>X8</th>
#       <th>...</th>
#       <th>X375</th>
#       <th>X376</th>
#       <th>X377</th>
#       <th>X378</th>
#       <th>X379</th>
#       <th>X380</th>
#       <th>X382</th>
#       <th>X383</th>
#       <th>X384</th>
#       <th>X385</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>130.81</td>
#       <td>37</td>
#       <td>23</td>
#       <td>20</td>
#       <td>0</td>
#       <td>3</td>
#       <td>27</td>
#       <td>9</td>
#       <td>14</td>
#       <td>...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>88.53</td>
#       <td>37</td>
#       <td>21</td>
#       <td>22</td>
#       <td>4</td>
#       <td>3</td>
#       <td>31</td>
#       <td>11</td>
#       <td>14</td>
#       <td>...</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7</td>
#       <td>76.26</td>
#       <td>24</td>
#       <td>24</td>
#       <td>38</td>
#       <td>2</td>
#       <td>3</td>
#       <td>30</td>
#       <td>9</td>
#       <td>23</td>
#       <td>...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>9</td>
#       <td>80.62</td>
#       <td>24</td>
#       <td>21</td>
#       <td>38</td>
#       <td>5</td>
#       <td>3</td>
#       <td>30</td>
#       <td>11</td>
#       <td>4</td>
#       <td>...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>13</td>
#       <td>78.02</td>
#       <td>24</td>
#       <td>23</td>
#       <td>38</td>
#       <td>5</td>
#       <td>3</td>
#       <td>14</td>
#       <td>3</td>
#       <td>13</td>
#       <td>...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 378 columns</p>
# </div>

# %%
n_comp = 12

# tSVD
tsvd = TruncatedSVD(n_components=n_comp, random_state=420)
tsvd_results_train = tsvd.fit_transform(train.drop(["y"], axis=1))
tsvd_results_test = tsvd.transform(test)

# PCA
pca = PCA(n_components=n_comp, random_state=420)
pca2_results_train = pca.fit_transform(train.drop(["y"], axis=1))
pca2_results_test = pca.transform(test)

# ICA
ica = FastICA(n_components=n_comp, random_state=420)
ica2_results_train = ica.fit_transform(train.drop(["y"], axis=1))
ica2_results_test = ica.transform(test)

# GRP
grp = GaussianRandomProjection(n_components=n_comp, eps=0.1, random_state=420)
grp_results_train = grp.fit_transform(train.drop(["y"], axis=1))
grp_results_test = grp.transform(test)

# SRP
srp = SparseRandomProjection(n_components=n_comp, dense_output=True, random_state=420)
srp_results_train = srp.fit_transform(train.drop(["y"], axis=1))
srp_results_test = srp.transform(test)

#save columns list before adding the decomposition components

usable_columns = list(set(train.columns) - set(['y']))

# Append decomposition components to datasets
for i in range(1, n_comp + 1):
    train['pca_' + str(i)] = pca2_results_train[:, i - 1]
    test['pca_' + str(i)] = pca2_results_test[:, i - 1]

    train['ica_' + str(i)] = ica2_results_train[:, i - 1]
    test['ica_' + str(i)] = ica2_results_test[:, i - 1]

    train['tsvd_' + str(i)] = tsvd_results_train[:, i - 1]
    test['tsvd_' + str(i)] = tsvd_results_test[:, i - 1]

    train['grp_' + str(i)] = grp_results_train[:, i - 1]
    test['grp_' + str(i)] = grp_results_test[:, i - 1]

    train['srp_' + str(i)] = srp_results_train[:, i - 1]
    test['srp_' + str(i)] = srp_results_test[:, i - 1]

#usable_columns = list(set(train.columns) - set(['y']))

y_train = train['y'].values
y_mean = np.mean(y_train)
id_test = test['ID'].values
#finaltrainset and finaltestset are data to be used only the stacked model (does not contain PCA, SVD... arrays) 
finaltrainset = train[usable_columns].values
finaltestset = test[usable_columns].values


'''Train the xgb model then predict the test data'''

xgb_params = {
    'n_trees': 520, 
    'eta': 0.0045,
    'max_depth': 4,
    'subsample': 0.93,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'base_score': y_mean, # base prediction = mean(target)
    'silent': 1
}
# NOTE: Make sure that the class is labeled 'class' in the data file

dtrain = xgb.DMatrix(train.drop('y', axis=1), y_train)
dtest = xgb.DMatrix(test)

num_boost_rounds = 1250
# train model
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=num_boost_rounds)
y_pred = model.predict(dtest)

'''Train the stacked models then predict the test data'''

stacked_pipeline = make_pipeline(
    StackingEstimator(estimator=LassoLarsCV(normalize=True)),
    StackingEstimator(estimator=GradientBoostingRegressor(learning_rate=0.001, loss="huber", max_depth=3, max_features=0.55, min_samples_leaf=18, min_samples_split=14, subsample=0.7)),
    LassoLarsCV()

)


stacked_pipeline.fit(finaltrainset, y_train)
results = stacked_pipeline.predict(finaltestset)

# %%
# evaluate pipeline
import time

t0 = time.time()
seed = 7
kfold = KFold(n_splits=10, random_state=seed)
resultscv = cross_val_score(stacked_pipeline, finaltrainset, y_train, cv=kfold) # xgb_model in sklearn wrapper
print(resultscv.mean())
print("Done: {:.1f} s".format(time.time() - t0))

# 0.578679683628
# Done: 50.0 s
# Out:
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.029e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:377: RuntimeWarning: overflow encountered in true_divide
#   g1 = arrayfuncs.min_pos((C - Cov) / (AA - corr_eq_dir + tiny))
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.002e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.002e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.339e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.314e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.019e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:381: RuntimeWarning: overflow encountered in true_divide
#   g2 = arrayfuncs.min_pos((C + Cov) / (AA + corr_eq_dir + tiny))
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.936e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=9.728e-03, with an active set of 18 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=7.504e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=6.630e-03, previous alpha=6.625e-03, with an active set of 29 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=2.369e-02, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.269e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.017e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.185e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.185e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.185e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.144e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.086e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.965e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 19 iterations, alpha=9.814e-03, previous alpha=9.764e-03, with an active set of 18 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 2 iterations, i.e. alpha=6.172e-02, with an active set of 2 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.737e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.737e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=3.047e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.853e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.805e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.751e-02, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=1.753e-02, previous alpha=1.737e-02, with an active set of 15 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.243e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=1.634e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.432e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.259e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.250e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.250e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.179e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.118e-02, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=1.032e-02, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=7.691e-03, with an active set of 18 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=7.382e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.536e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=4.248e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.264e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.264e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.250e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 48 iterations, i.e. alpha=3.175e-03, with an active set of 48 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 49 iterations, i.e. alpha=2.990e-03, with an active set of 49 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 60 iterations, i.e. alpha=2.647e-03, with an active set of 60 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 60 iterations, i.e. alpha=2.647e-03, with an active set of 60 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 71 iterations, alpha=2.389e-03, previous alpha=2.379e-03, with an active set of 70 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=2.967e-03, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.980e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.937e-03, with an active set of 42 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=2.937e-03, with an active set of 42 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 55 iterations, i.e. alpha=2.474e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=2.115e-03, with an active set of 70 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=2.115e-03, with an active set of 70 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=2.115e-03, with an active set of 70 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 72 iterations, i.e. alpha=2.115e-03, with an active set of 70 regressors, and the smallest cholesky pivot element being 5.771e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 80 iterations, i.e. alpha=1.912e-03, with an active set of 78 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 80 iterations, i.e. alpha=1.912e-03, with an active set of 78 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 82 iterations, i.e. alpha=1.868e-03, with an active set of 80 regressors, and the smallest cholesky pivot element being 4.712e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 96 iterations, i.e. alpha=1.584e-03, with an active set of 94 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 97 iterations, i.e. alpha=1.569e-03, with an active set of 95 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 98 iterations, alpha=1.571e-03, previous alpha=1.569e-03, with an active set of 95 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=6.063e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=5.938e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=4.991e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 22 iterations, i.e. alpha=4.665e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=4.226e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=4.158e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 27 iterations, i.e. alpha=4.098e-03, with an active set of 27 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 32 iterations, i.e. alpha=3.713e-03, with an active set of 32 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=3.425e-03, with an active set of 41 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 41 iterations, i.e. alpha=3.425e-03, with an active set of 41 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 44 iterations, alpha=3.431e-03, previous alpha=3.301e-03, with an active set of 43 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=3.029e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:377: RuntimeWarning: overflow encountered in true_divide
#   g1 = arrayfuncs.min_pos((C - Cov) / (AA - corr_eq_dir + tiny))
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.002e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=2.002e-02, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.339e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.314e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.019e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:381: RuntimeWarning: overflow encountered in true_divide
#   g2 = arrayfuncs.min_pos((C + Cov) / (AA + corr_eq_dir + tiny))
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=9.936e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 18 iterations, i.e. alpha=9.728e-03, with an active set of 18 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 28 iterations, i.e. alpha=7.504e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 32 iterations, alpha=6.630e-03, previous alpha=6.625e-03, with an active set of 29 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.896e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=2.725e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=2.725e-02, with an active set of 5 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=2.401e-02, with an active set of 8 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.398e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=2.398e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.732e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=1.579e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 15 iterations, i.e. alpha=1.346e-02, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=1.324e-02, with an active set of 17 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 20 iterations, i.e. alpha=1.179e-02, with an active set of 20 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=1.149e-02, with an active set of 21 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=1.003e-02, with an active set of 23 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 25 iterations, i.e. alpha=9.327e-03, with an active set of 25 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 29 iterations, alpha=9.343e-03, previous alpha=8.889e-03, with an active set of 28 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.696e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.348e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.332e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 16 iterations, alpha=1.230e-02, previous alpha=1.230e-02, with an active set of 15 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=1.599e-02, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 11 iterations, i.e. alpha=1.534e-02, with an active set of 11 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=1.026e-02, with an active set of 14 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=7.259e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=7.259e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=7.259e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=7.176e-03, with an active set of 24 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 29 iterations, alpha=7.085e-03, previous alpha=6.967e-03, with an active set of 24 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 7 iterations, i.e. alpha=6.832e-03, with an active set of 7 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.416e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 45 iterations, i.e. alpha=3.416e-03, with an active set of 45 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=2.943e-03, with an active set of 52 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=2.841e-03, with an active set of 56 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 64 iterations, alpha=2.763e-03, previous alpha=2.750e-03, with an active set of 63 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=5.490e-03, with an active set of 17 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=3.866e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 46 iterations, i.e. alpha=3.135e-03, with an active set of 44 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=2.815e-03, with an active set of 50 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 53 iterations, i.e. alpha=2.745e-03, with an active set of 51 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 53 iterations, i.e. alpha=2.745e-03, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 53 iterations, i.e. alpha=2.745e-03, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 56 iterations, i.e. alpha=2.606e-03, with an active set of 54 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=2.432e-03, with an active set of 65 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 83 iterations, alpha=2.109e-03, previous alpha=2.105e-03, with an active set of 80 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=8.653e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=6.427e-03, with an active set of 11 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=5.716e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 17 iterations, i.e. alpha=5.716e-03, with an active set of 15 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 24 iterations, i.e. alpha=5.232e-03, with an active set of 22 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.113e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=3.847e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=3.847e-03, with an active set of 37 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 42 iterations, i.e. alpha=3.709e-03, with an active set of 40 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 53 iterations, i.e. alpha=3.406e-03, with an active set of 51 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# ...
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=6.528e-03, with an active set of 31 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 38 iterations, i.e. alpha=6.003e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=5.993e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 39 iterations, i.e. alpha=5.993e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 40 iterations, i.e. alpha=5.917e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 42 iterations, alpha=5.839e-03, previous alpha=5.704e-03, with an active set of 37 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 4 iterations, i.e. alpha=2.286e-02, with an active set of 4 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.143e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 12 iterations, i.e. alpha=1.143e-02, with an active set of 12 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 13 iterations, i.e. alpha=1.022e-02, with an active set of 13 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 21 iterations, i.e. alpha=6.693e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 23 iterations, i.e. alpha=6.475e-03, with an active set of 21 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 14 iterations, i.e. alpha=5.145e-03, with an active set of 14 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 30 iterations, i.e. alpha=3.881e-03, with an active set of 30 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 57 iterations, i.e. alpha=2.572e-03, with an active set of 55 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 61 iterations, i.e. alpha=2.355e-03, with an active set of 59 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=2.122e-03, with an active set of 65 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=2.122e-03, with an active set of 65 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 67 iterations, i.e. alpha=2.122e-03, with an active set of 65 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=1.936e-03, with an active set of 75 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 77 iterations, i.e. alpha=1.936e-03, with an active set of 75 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 85 iterations, i.e. alpha=1.732e-03, with an active set of 83 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 102 iterations, i.e. alpha=1.437e-03, with an active set of 98 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 102 iterations, i.e. alpha=1.437e-03, with an active set of 98 regressors, and the smallest cholesky pivot element being 2.581e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 109 iterations, alpha=1.367e-03, previous alpha=1.365e-03, with an active set of 102 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 8 iterations, i.e. alpha=6.809e-03, with an active set of 8 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 26 iterations, i.e. alpha=4.265e-03, with an active set of 26 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 34 iterations, i.e. alpha=3.816e-03, with an active set of 34 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.752e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=3.752e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=3.063e-03, with an active set of 50 regressors, and the smallest cholesky pivot element being 1.825e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 62 iterations, alpha=2.635e-03, previous alpha=2.631e-03, with an active set of 61 regressors.
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 5 iterations, i.e. alpha=8.489e-03, with an active set of 5 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 6 iterations, i.e. alpha=8.089e-03, with an active set of 6 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 9 iterations, i.e. alpha=6.337e-03, with an active set of 9 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=5.213e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=5.213e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 16 iterations, i.e. alpha=5.213e-03, with an active set of 16 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 19 iterations, i.e. alpha=4.826e-03, with an active set of 19 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.284e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 1.490e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 35 iterations, i.e. alpha=4.284e-03, with an active set of 35 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 36 iterations, i.e. alpha=4.264e-03, with an active set of 36 regressors, and the smallest cholesky pivot element being 1.054e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 50 iterations, i.e. alpha=3.332e-03, with an active set of 50 regressors, and the smallest cholesky pivot element being 2.107e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 52 iterations, i.e. alpha=3.282e-03, with an active set of 52 regressors, and the smallest cholesky pivot element being 3.650e-08
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:309: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 59 iterations, i.e. alpha=2.972e-03, with an active set of 59 regressors, and the smallest cholesky pivot element being 2.220e-16
#   ConvergenceWarning)
# /Users/dario/anaconda/envs/datasci/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:334: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 61 iterations, alpha=3.215e-03, previous alpha=2.967e-03, with an active set of 60 regressors.
#   ConvergenceWarning)
# 0.578679683628
# Done: 50.0 s

# %%
'''R2 Score on the entire Train data when averaging'''

print('R2 score on train data:')
print(r2  _score(y_train,stacked_pipeline.predict(finaltrainset)*0.2855 + model.predict(dtrain)*0.7145))

'''Average the prediction on test data of both models then save it on a csv file'''

sub = pd.DataFrame()
sub['ID'] = id_test
sub['y'] = y_pred*0.75 + results*0.25
sub.to_csv('stacked-models.csv', index=False)


# Any results you write to the current directory are saved as output.
